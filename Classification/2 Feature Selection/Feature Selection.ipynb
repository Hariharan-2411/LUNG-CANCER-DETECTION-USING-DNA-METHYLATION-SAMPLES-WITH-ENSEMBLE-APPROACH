# %%
import pickle
with open('Dependency\datacollected.pkl', 'rb') as f:
    X_train, X_test, y_train, y_test = pickle.load(f)

# %%
from sklearn.linear_model import LassoCV
import pandas as pd

model = LassoCV(cv=5)
model.fit(X_train, y_train)

# Print the list of features with non-zero coefficients
selected_features = list(X_train.columns[model.coef_ != 0])
print("Selected features:", selected_features)
features_select = selected_features
features_select.extend(["Stage"])
features_select
# Out:
# Selected features: ['cg14159672']
# ['cg14159672', 'Stage']

# %%
i = 0
j = 5260
sf2 = []
counter = 0
while (j<=26300):
  model = LassoCV(cv=5)
  model.fit(X_train.iloc[:,i:j], y_train)
  # Print the list of features with non-zero coefficients
  selected_features = list(X_train.iloc[:,i:j].columns[model.coef_ != 0])
  sf2.extend(selected_features)
  
  i = j + 1;
  j = j + 5260;
  counter = counter + 1
  print(counter)
print(sf2)
features_select2 = sf2
features_select2.extend(["Stage"])
features_select2
# Out:
# 1
# 2
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.757e-02, tolerance: 1.442e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.029e-02, tolerance: 1.442e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.572e-02, tolerance: 1.465e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e-02, tolerance: 1.307e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.040e-02, tolerance: 1.529e-02
#   model = cd_fast.enet_coordinate_descent(
# 3
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.329e-02, tolerance: 1.307e-02
#   model = cd_fast.enet_coordinate_descent(
# 4
# 5
# ['cg14159672', 'cg23244913']
# ['cg14159672', 'cg23244913', 'Stage']

# %%
X_train_fs = X_train[features_select2[:-1]]
X_train_fs
# Out:
# ID_REF    cg14159672 cg23244913
# GSM813179   0.716134   0.581948
# GSM813231   0.195717   0.093763
# GSM813240   0.082674   0.259406
# GSM813215   0.750396   0.365543
# GSM813209   0.524709   0.349833
# ...              ...        ...
# GSM813282   0.863398   0.151719
# GSM813188    0.09332   0.133903
# GSM813268   0.027111   0.106183
# GSM813227   0.811788   0.522429
# GSM813278   0.922202   0.098623
#
# [74 rows x 2 columns]

# %%
X_test_fs = X_test[features_select2[:-1]]
X_test_fs
# Out:
# ID_REF    cg14159672 cg23244913
# GSM813256   0.060673    0.48253
# GSM813178   0.442869   0.137789
# GSM813216   0.190709   0.125386
# GSM813245   0.287862   0.377914
# GSM813184   0.107168   0.054689
# GSM813221   0.721016   0.610437
# GSM813246   0.292761   0.155739
# GSM813242   0.169271    0.13543
# GSM813223   0.389993   0.634655
# GSM813185   0.449981   0.307435
# GSM813274   0.185316   0.160549
# GSM813210   0.483442   0.070976
# GSM813259   0.153029   0.562018
# GSM813290    0.15067   0.105822
# GSM813192   0.355023   0.212126
# GSM813174   0.084279    0.08834
# GSM813248   0.144668   0.087808
# GSM813200   0.104755   0.051154
# GSM813257   0.432247   0.608197
# GSM813229   0.765964   0.588079
# GSM813279   0.601559   0.763559
# GSM813267   0.661992   0.694651
# GSM813186   0.063246   0.040361
# GSM813205   0.151443   0.715947
# GSM813243   0.455768   0.660822
# GSM813289     0.3133   0.504582
# GSM813284   0.124874   0.143026
# GSM813196   0.161091   0.201107
# GSM813220   0.113475   0.150451
# GSM813283   0.886543   0.460705
# GSM813254   0.056628   0.103255
# GSM813189   0.166756   0.734575
# GSM813204    0.09312   0.073009
# GSM813280   0.412729   0.143368
# GSM813183   0.905233   0.101449
# GSM813207   0.790748   0.069988
# GSM813238   0.078285   0.078635
# GSM813241   0.097213   0.784674
# GSM813202   0.097687    0.17828
# GSM813218   0.095781   0.107999

# %%
with open('FeatureSelectedData.pkl', 'wb') as f:
    pickle.dump((X_train_fs, y_train, X_test_fs, y_test), f)
